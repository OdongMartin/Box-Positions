# %%
import sys

original_stdout = sys.stdout

with open('output.csv', 'w') as f:
    sys.stdout = f
    # print certain columns
    with open('../Raw sputum/raw sputum storage positions.csv', 'r') as f1:
        lines = f1.readlines()
        for line in lines:    
            # print certain columns by name
            # print(line)
            
            if 'Name' in line:
                columns = line.split(',')  # the for loop gets each row separated by comma
                name_index = columns.index('Name')
                box_index = columns.index('Box')
                # position_index = columns.index('Pos_No')
                
                # print(f'Indices - Name: {name_index}, Box: {box_index}')
                continue  # skip to next iteration after processing header row
            columns = line.split(',') # the for loop gets each row separated by comma
            print(columns[name_index],columns[box_index],columns[-1] , sep=",")  # prints certain columns
            # create file to output the printed columns
            # with open('box_pos.csv', 'w') as out_file:
            #     out_file.write(f'{columns[name_index]},{columns[box_index]},{columns[-1]}\n')

        # append to already existing file
        # with open('output.csv', 'a') as out_file:
        #     for line in lines:
        #         columns = line.split(',')
        #         out_file.write(f'{columns[name_index]},{columns[box_index]},{columns[-1]}\n')
    with open('../Raw sputum/raw sputum storage positions 29-oct-2025.csv', 'r') as f2:
        lines = f2.readlines()
        for line in lines:    
        # print certain columns by name
        # print(line)
        
            if 'Name' in line:
                columns = line.split(',')  # the for loop gets each row separated by comma
                name_index = columns.index('Name')
                box_index = columns.index('Box')
                
                # print(f'Indices - Name: {name_index}, Box: {box_index}')
                continue  # skip to next iteration after processing header row
            columns = line.split(',') # the for loop gets each row separated by comma
            print(columns[name_index],columns[box_index],columns[-1], sep=',')  # prints certain columns
            # create file to output the printed columns
            # with open('box_pos.csv', 'a') as out_file:
            #     out_file.write(f'{columns[name_index]},{columns[box_index]},{columns[-1]}\n')
            
        
        # print(columns)
sys.stdout = original_stdout
